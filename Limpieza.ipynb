# %% [markdown]
# # MACHINE LEARNING LEAGUE OF LEGENDS

# %%
https://huggingface.co/datasets/gptilt/lol-basic-matches-challenger-10k/tree/main/matches

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfam = pd.read_parquet('region_americas-00000.parquet')
dfam.to_csv("region_americas-00000.csv", index=False)

# %%
dfas = pd.read_parquet("region_asia-00000.parquet")
dfas.to_csv("region_asia-00000.csv", index=False)

# %%
dfeu = pd.read_parquet("region_europe-00000.parquet")
dfeu.to_csv("region_europe-00000.csv", index=False)

# %%
df = pd.read_csv('region_americas-00000.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3334 entries, 0 to 3333
# Data columns (total 49 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   endOfGameResult             3334 non-null   object
#  1   gameDuration                3334 non-null   int64
#  2   gameEndTimestamp            3334 non-null   int64
#  3   gameId                      3334 non-null   int64
#  4   gameStartTimestamp          3334 non-null   int64
#  5   gameVersion                 3334 non-null   object
#  6   matchId                     3334 non-null   object
#  7   platformId                  3334 non-null   object
#  8   region                      3334 non-null   object
#  9   team_100_EPIC_MONSTER_KILL  3334 non-null   int64
#  10  team_100_FIRST_BLOOD        3334 non-null   int64
#  11  team_100_FIRST_TURRET       3334 non-null   int64
#  12  team_100_atakhan_first      3334 non-null   bool
# ...

# %%
df[['team_100_FIRST_BLOOD','team_200_FIRST_BLOOD','winner_team_id']][df['team_200_FIRST_BLOOD'] == 2]
# Out:
#       team_100_FIRST_BLOOD  team_200_FIRST_BLOOD  winner_team_id
# 2053                     1                     2             200

# %%
df['team_200_FIRST_BLOOD'].value_counts()
# Out:
# team_200_FIRST_BLOOD
# 1001    1687
# 3       1601
# 0         39
# 1          6
# 2          1
# Name: count, dtype: int64

# %%
df = df.drop(columns = 'tournamentCode')

# %%
df = df.drop(columns = 'endOfGameResult')

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(numeric_only=True),vmin=-1,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
df = df.drop(columns = ['gameEndTimestamp','gameId','gameStartTimestamp'])

# %%
df_p = df[['gameDuration', 'team_100_FIRST_BLOOD','team_100_FIRST_TURRET']]
