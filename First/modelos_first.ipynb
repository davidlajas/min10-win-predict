# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.svm import SVC
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.cluster import KMeans
import numpy as np
from sklearn.cluster import DBSCAN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('data/datoslimpios.csv')

# %%
df
# Out:
#       duracion_partida  equipo_0_atakhan_prim  equipo_0_baron_prim  \
# 0                 1524                   True                False
# 1                 1939                  False                 True
# 2                 1911                   True                 True
# 3                 1691                   True                False
# 4                 1580                  False                False
# ...                ...                    ...                  ...
# 6848              1735                   True                 True
# 6849              1769                   True                 True
# 6850              2039                   True                False
# 6851              1768                  False                False
# 6852              1629                  False                False
#
#       equipo_1_atakhan_prim  equipo_1_baron_prim  equipo_dragon_prim  \
# 0                     False                False                   0
# 1                      True                False                   1
# 2                     False                False                   1
# 3                     False                False                   1
# 4                      True                False                   0
# ...                     ...                  ...                 ...
# 6848                  False                False                   0
# 6849                  False                False                   0
# 6850                  False                 True                   0
# 6851                   True                 True                   1
# 6852                   True                False                   1
#
#       equipo_horda_prim  equipo_kill_prim  equipo_inhib_prim  \
# 0                     1                 0                  1
# 1                     0                 1                  1
# 2                     1                 1                  0
# 3                     0                 0                  0
# 4                     0                 0                  1
# ...                 ...               ...                ...
# 6848                  1                 0                  0
# 6849                  1                 0                  0
# 6850                  1                 1                  0
# 6851                  1                 0                  1
# 6852                  1                 1                  1
#
#       equipo_heraldo_prim  equipo_ganador
# 0                       0               1
# 1                       0               1
# 2                       1               0
# 3                       0               0
# 4                       1               1
# ...                   ...             ...
# 6848                    0               0
# 6849                    0               0
# 6850                    1               0
# 6851                    1               1
# 6852                    1               1
#
# [6853 rows x 11 columns]

# %%
df.describe()
# Out:
#        duracion_partida  equipo_dragon_prim  equipo_horda_prim  \
# count       6853.000000         6853.000000        6853.000000
# mean        1762.256676            0.626441           0.401284
# std          289.057131            0.483784           0.490194
# min          971.000000            0.000000           0.000000
# 25%         1588.000000            0.000000           0.000000
# 50%         1725.000000            1.000000           0.000000
# 75%         1920.000000            1.000000           1.000000
# max         3264.000000            1.000000           1.000000
#
#        equipo_kill_prim  equipo_inhib_prim  equipo_heraldo_prim  \
# count       6853.000000        6853.000000          6853.000000
# mean           0.491026           0.481979             0.394426
# std            0.499956           0.499712             0.488763
# min            0.000000           0.000000             0.000000
# 25%            0.000000           0.000000             0.000000
# 50%            0.000000           0.000000             0.000000
# 75%            1.000000           1.000000             1.000000
# max            1.000000           1.000000             1.000000
#
#        equipo_ganador
# count     6853.000000
# mean         0.483876
# std          0.499776
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000

# %%
X = df.drop(columns='equipo_ganador')
y = df['equipo_ganador']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42,test_size=0.2)

# %% [markdown]
# ## Standar Scaler

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(X_train)
X_train_scal = scaler.transform(X_train)
X_test_scal = scaler.transform(X_test)
X_scal = scaler.transform(X)

lr_scal = LogisticRegression(max_iter=500)
lr_scal.fit(X_train_scal,y_train)
# Out:
# LogisticRegression(max_iter=500)

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_scal, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
pred_proba_scal = lr_scal.predict_proba(X_test_scal)[:,1]
pred_scal = lr_scal.predict(X_test_scal)
print(pred_proba_scal)
print(pred_scal)
# Out:
# [0.94087586 0.95735995 0.1221821  ... 0.02511963 0.95570134 0.03380361]
# [1 1 0 ... 0 1 0]

# %%
print('confusion_matrix: ', confusion_matrix(y_test, pred_scal))
print('accuracy_score: ', accuracy_score(y_test, pred_scal))
print('precision_score: ', precision_score(y_test, pred_scal))
print('recall_score: ', recall_score(y_test, pred_scal))
print('f1_score: ', f1_score(y_test, pred_scal))
print('roc_auc_score: ', roc_auc_score(y_test, pred_proba_scal))
# Out:
# confusion_matrix:  [[693  41]
#  [ 63 574]]
# accuracy_score:  0.9241429613420861
# precision_score:  0.9333333333333333
# recall_score:  0.9010989010989011
# f1_score:  0.9169329073482428
# roc_auc_score:  0.9651326680326292

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
gb_clf = GradientBoostingClassifier()

# %%
param_gb_clf = {
    "n_estimators": [100, 200, 300],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [2, 3, 4]
}

grid_gb_clf = GridSearchCV(
    gb_clf,
    param_gb_clf,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
    verbose=2
)

grid_gb_clf.fit(X_train_scal, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [2, 3, 4],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy', verbose=2)

# %%
print(grid_gb_clf.best_params_)
print(grid_gb_clf.best_score_)
# Out:
# {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300}
# 0.9213816380440351

# %%
gb_clf.fit(X_train_scal, y_train)
pred_proba_gbclf = gb_clf.predict_proba(X_test_scal)[:,1]
pred_gbclf = gb_clf.predict_proba(X_test_scal)

# %%
grid_proba_clf = grid_gb_clf.predict(X_test_scal)
grid_pred_proba_clf = gb_clf.predict_proba(X_test_scal)[:,1]

# %%
print('confusion_matrix: ', confusion_matrix(y_test, grid_proba_clf))
print('accuracy_score: ', accuracy_score(y_test, grid_proba_clf))
print('precision_score: ', precision_score(y_test, grid_proba_clf))
print('recall_score: ', recall_score(y_test, grid_proba_clf))
print('f1_score: ', f1_score(y_test, grid_proba_clf))
print('roc_auc_score: ', roc_auc_score(y_test, grid_pred_proba_clf))
# Out:
# confusion_matrix:  [[700  34]
#  [ 63 574]]
# accuracy_score:  0.9292487235594457
# precision_score:  0.944078947368421
# recall_score:  0.9010989010989011
# f1_score:  0.9220883534136546
# roc_auc_score:  0.9809766916617831

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint, uniform

rf = RandomForestClassifier()

param_dist = {
    "n_estimators": randint(100, 600),
    "max_depth": list(range(5, 31)),
}

rand_rf = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=60,
    cv=5,
    scoring="accuracy",
    verbose=2,
    random_state=42
)

rand_rf.fit(X_train_scal, y_train)

print(rand_rf.best_params_)
print(rand_rf.best_score_)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] END .....................max_depth=11, n_estimators=535; total time=   1.8s
# [CV] END .....................max_depth=11, n_estimators=535; total time=   1.4s
# [CV] END .....................max_depth=11, n_estimators=535; total time=   1.5s
# [CV] END .....................max_depth=11, n_estimators=535; total time=   1.4s
# [CV] END .....................max_depth=11, n_estimators=535; total time=   1.4s
# [CV] END .....................max_depth=19, n_estimators=206; total time=   0.5s
# [CV] END .....................max_depth=19, n_estimators=206; total time=   0.5s
# [CV] END .....................max_depth=19, n_estimators=206; total time=   0.5s
# [CV] END .....................max_depth=19, n_estimators=206; total time=   0.5s
# [CV] END .....................max_depth=19, n_estimators=206; total time=   0.5s
# [CV] END .....................max_depth=12, n_estimators=288; total time=   0.8s
# [CV] END .....................max_depth=12, n_estimators=288; total time=   0.7s
# [CV] END .....................max_depth=12, n_estimators=288; total time=   0.7s
# [CV] END .....................max_depth=12, n_estimators=288; total time=   0.8s
# [CV] END .....................max_depth=12, n_estimators=288; total time=   0.8s
# [CV] END .....................max_depth=25, n_estimators=202; total time=   0.8s
# [CV] END .....................max_depth=25, n_estimators=202; total time=   0.7s
# [CV] END .....................max_depth=25, n_estimators=202; total time=   0.6s
# [CV] END .....................max_depth=25, n_estimators=202; total time=   0.5s
# [CV] END .....................max_depth=25, n_estimators=202; total time=   0.6s
# [CV] END .....................max_depth=30, n_estimators=566; total time=   1.6s
# [CV] END .....................max_depth=30, n_estimators=566; total time=   1.6s
# [CV] END .....................max_depth=30, n_estimators=566; total time=   1.6s
# [CV] END .....................max_depth=30, n_estimators=566; total time=   1.5s
# [CV] END .....................max_depth=30, n_estimators=566; total time=   1.6s
# [CV] END .....................max_depth=27, n_estimators=430; total time=   1.2s
# [CV] END .....................max_depth=27, n_estimators=430; total time=   1.2s
# [CV] END .....................max_depth=27, n_estimators=430; total time=   1.2s
# [CV] END .....................max_depth=27, n_estimators=430; total time=   1.2s
# [CV] END .....................max_depth=27, n_estimators=430; total time=   1.1s
# [CV] END .....................max_depth=15, n_estimators=187; total time=   0.5s
# [CV] END .....................max_depth=15, n_estimators=187; total time=   0.4s
# [CV] END .....................max_depth=15, n_estimators=187; total time=   0.4s
# [CV] END .....................max_depth=15, n_estimators=187; total time=   0.4s
# [CV] END .....................max_depth=15, n_estimators=187; total time=   0.4s
# [CV] END .....................max_depth=25, n_estimators=199; total time=   0.5s
# [CV] END .....................max_depth=25, n_estimators=199; total time=   0.5s
# [CV] END .....................max_depth=25, n_estimators=199; total time=   0.5s
# [CV] END .....................max_depth=25, n_estimators=199; total time=   0.5s
# [CV] END .....................max_depth=25, n_estimators=199; total time=   0.5s
# [CV] END .....................max_depth=12, n_estimators=251; total time=   0.6s
# [CV] END .....................max_depth=12, n_estimators=251; total time=   0.6s
# [CV] END .....................max_depth=12, n_estimators=251; total time=   0.6s
# [CV] END .....................max_depth=12, n_estimators=251; total time=   0.7s
# [CV] END .....................max_depth=12, n_estimators=251; total time=   0.6s
# [CV] END ......................max_depth=7, n_estimators=249; total time=   0.5s
# [CV] END ......................max_depth=7, n_estimators=249; total time=   0.5s
# [CV] END ......................max_depth=7, n_estimators=249; total time=   0.5s
# [CV] END ......................max_depth=7, n_estimators=249; total time=   0.5s
# [CV] END ......................max_depth=7, n_estimators=249; total time=   0.5s
# [CV] END .....................max_depth=25, n_estimators=357; total time=   0.9s
# [CV] END .....................max_depth=25, n_estimators=357; total time=   1.0s
# [CV] END .....................max_depth=25, n_estimators=357; total time=   0.9s
# [CV] END .....................max_depth=25, n_estimators=357; total time=   1.0s
# [CV] END .....................max_depth=25, n_estimators=357; total time=   1.0s
# [CV] END .....................max_depth=28, n_estimators=591; total time=   1.7s
# [CV] END .....................max_depth=28, n_estimators=591; total time=   1.7s
# [CV] END .....................max_depth=28, n_estimators=591; total time=   1.6s
# [CV] END .....................max_depth=28, n_estimators=591; total time=   1.7s
# [CV] END .....................max_depth=28, n_estimators=591; total time=   1.7s
# [CV] END .....................max_depth=10, n_estimators=485; total time=   1.4s
# [CV] END .....................max_depth=10, n_estimators=485; total time=   1.7s
# [CV] END .....................max_depth=10, n_estimators=485; total time=   1.4s
# [CV] END .....................max_depth=10, n_estimators=485; total time=   1.3s
# [CV] END .....................max_depth=10, n_estimators=485; total time=   1.3s
# [CV] END .....................max_depth=25, n_estimators=260; total time=   0.8s
# [CV] END .....................max_depth=25, n_estimators=260; total time=   0.8s
# [CV] END .....................max_depth=25, n_estimators=260; total time=   0.7s
# [CV] END .....................max_depth=25, n_estimators=260; total time=   0.7s
# [CV] END .....................max_depth=25, n_estimators=260; total time=   0.7s
# [CV] END .....................max_depth=16, n_estimators=413; total time=   1.1s
# [CV] END .....................max_depth=16, n_estimators=413; total time=   1.1s
# [CV] END .....................max_depth=16, n_estimators=413; total time=   1.1s
# [CV] END .....................max_depth=16, n_estimators=413; total time=   1.2s
# [CV] END .....................max_depth=16, n_estimators=413; total time=   1.1s
# [CV] END .....................max_depth=26, n_estimators=352; total time=   0.9s
# [CV] END .....................max_depth=26, n_estimators=352; total time=   0.9s
# [CV] END .....................max_depth=26, n_estimators=352; total time=   1.0s
# [CV] END .....................max_depth=26, n_estimators=352; total time=   1.4s
# [CV] END .....................max_depth=26, n_estimators=352; total time=   1.1s
# [CV] END .....................max_depth=16, n_estimators=444; total time=   1.5s
# [CV] END .....................max_depth=16, n_estimators=444; total time=   1.2s
# [CV] END .....................max_depth=16, n_estimators=444; total time=   1.2s
# [CV] END .....................max_depth=16, n_estimators=444; total time=   1.3s
# [CV] END .....................max_depth=16, n_estimators=444; total time=   1.3s
# [CV] END .....................max_depth=21, n_estimators=574; total time=   1.8s
# [CV] END .....................max_depth=21, n_estimators=574; total time=   1.6s
# [CV] END .....................max_depth=21, n_estimators=574; total time=   1.6s
# [CV] END .....................max_depth=21, n_estimators=574; total time=   1.7s
# [CV] END .....................max_depth=21, n_estimators=574; total time=   2.0s
# [CV] END .....................max_depth=14, n_estimators=575; total time=   1.7s
# [CV] END .....................max_depth=14, n_estimators=575; total time=   1.6s
# [CV] END .....................max_depth=14, n_estimators=575; total time=   1.6s
# [CV] END .....................max_depth=14, n_estimators=575; total time=   2.0s
# [CV] END .....................max_depth=14, n_estimators=575; total time=   1.9s
# [CV] END .....................max_depth=20, n_estimators=370; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=370; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=370; total time=   1.4s
# [CV] END .....................max_depth=20, n_estimators=370; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=370; total time=   1.4s
# [CV] END .....................max_depth=19, n_estimators=545; total time=   2.4s
# [CV] END .....................max_depth=19, n_estimators=545; total time=   3.3s
# [CV] END .....................max_depth=19, n_estimators=545; total time=   3.5s
# [CV] END .....................max_depth=19, n_estimators=545; total time=   3.7s
# [CV] END .....................max_depth=19, n_estimators=545; total time=   3.6s
# [CV] END .....................max_depth=23, n_estimators=463; total time=   3.1s
# [CV] END .....................max_depth=23, n_estimators=463; total time=   3.1s
# [CV] END .....................max_depth=23, n_estimators=463; total time=   3.1s
# [CV] END .....................max_depth=23, n_estimators=463; total time=   2.9s
# [CV] END .....................max_depth=23, n_estimators=463; total time=   3.2s
# [CV] END .....................max_depth=27, n_estimators=343; total time=   2.4s
# [CV] END .....................max_depth=27, n_estimators=343; total time=   2.4s
# [CV] END .....................max_depth=27, n_estimators=343; total time=   2.3s
# [CV] END .....................max_depth=27, n_estimators=343; total time=   2.3s
# [CV] END .....................max_depth=27, n_estimators=343; total time=   2.4s
# [CV] END .....................max_depth=29, n_estimators=230; total time=   1.5s
# [CV] END .....................max_depth=29, n_estimators=230; total time=   1.6s
# [CV] END .....................max_depth=29, n_estimators=230; total time=   1.6s
# [CV] END .....................max_depth=29, n_estimators=230; total time=   1.5s
# [CV] END .....................max_depth=29, n_estimators=230; total time=   1.6s
# [CV] END ......................max_depth=9, n_estimators=406; total time=   2.6s
# [CV] END ......................max_depth=9, n_estimators=406; total time=   2.0s
# [CV] END ......................max_depth=9, n_estimators=406; total time=   2.5s
# [CV] END ......................max_depth=9, n_estimators=406; total time=   2.6s
# [CV] END ......................max_depth=9, n_estimators=406; total time=   2.5s
# [CV] END .....................max_depth=11, n_estimators=120; total time=   0.7s
# [CV] END .....................max_depth=11, n_estimators=120; total time=   0.8s
# [CV] END .....................max_depth=11, n_estimators=120; total time=   0.7s
# [CV] END .....................max_depth=11, n_estimators=120; total time=   0.7s
# [CV] END .....................max_depth=11, n_estimators=120; total time=   0.8s
# [CV] END .....................max_depth=13, n_estimators=266; total time=   1.9s
# [CV] END .....................max_depth=13, n_estimators=266; total time=   2.0s
# [CV] END .....................max_depth=13, n_estimators=266; total time=   1.3s
# [CV] END .....................max_depth=13, n_estimators=266; total time=   1.0s
# [CV] END .....................max_depth=13, n_estimators=266; total time=   0.8s
# [CV] END .....................max_depth=22, n_estimators=487; total time=   1.4s
# [CV] END .....................max_depth=22, n_estimators=487; total time=   1.4s
# [CV] END .....................max_depth=22, n_estimators=487; total time=   1.3s
# [CV] END .....................max_depth=22, n_estimators=487; total time=   1.4s
# [CV] END .....................max_depth=22, n_estimators=487; total time=   1.3s
# [CV] END .....................max_depth=29, n_estimators=415; total time=   1.1s
# [CV] END .....................max_depth=29, n_estimators=415; total time=   1.1s
# [CV] END .....................max_depth=29, n_estimators=415; total time=   1.1s
# [CV] END .....................max_depth=29, n_estimators=415; total time=   1.1s
# [CV] END .....................max_depth=29, n_estimators=415; total time=   1.1s
# [CV] END .....................max_depth=18, n_estimators=341; total time=   0.9s
# [CV] END .....................max_depth=18, n_estimators=341; total time=   0.9s
# [CV] END .....................max_depth=18, n_estimators=341; total time=   0.9s
# [CV] END .....................max_depth=18, n_estimators=341; total time=   0.9s
# [CV] END .....................max_depth=18, n_estimators=341; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=364; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=364; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=364; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=364; total time=   1.0s
# [CV] END .....................max_depth=30, n_estimators=364; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=152; total time=   0.3s
# [CV] END .....................max_depth=30, n_estimators=152; total time=   0.3s
# [CV] END .....................max_depth=30, n_estimators=152; total time=   0.3s
# [CV] END .....................max_depth=30, n_estimators=152; total time=   0.3s
# [CV] END .....................max_depth=30, n_estimators=152; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=439; total time=   0.9s
# [CV] END ......................max_depth=6, n_estimators=439; total time=   0.9s
# [CV] END ......................max_depth=6, n_estimators=439; total time=   0.9s
# [CV] END ......................max_depth=6, n_estimators=439; total time=   0.8s
# [CV] END ......................max_depth=6, n_estimators=439; total time=   0.9s
# [CV] END .....................max_depth=19, n_estimators=543; total time=   1.5s
# [CV] END .....................max_depth=19, n_estimators=543; total time=   1.5s
# [CV] END .....................max_depth=19, n_estimators=543; total time=   1.4s
# [CV] END .....................max_depth=19, n_estimators=543; total time=   1.4s
# [CV] END .....................max_depth=19, n_estimators=543; total time=   1.5s
# [CV] END .....................max_depth=11, n_estimators=527; total time=   1.4s
# [CV] END .....................max_depth=11, n_estimators=527; total time=   1.4s
# [CV] END .....................max_depth=11, n_estimators=527; total time=   1.4s
# [CV] END .....................max_depth=11, n_estimators=527; total time=   1.5s
# [CV] END .....................max_depth=11, n_estimators=527; total time=   1.4s
# [CV] END .....................max_depth=12, n_estimators=530; total time=   1.5s
# [CV] END .....................max_depth=12, n_estimators=530; total time=   1.5s
# [CV] END .....................max_depth=12, n_estimators=530; total time=   2.2s
# [CV] END .....................max_depth=12, n_estimators=530; total time=   1.6s
# [CV] END .....................max_depth=12, n_estimators=530; total time=   1.5s
# [CV] END ......................max_depth=7, n_estimators=305; total time=   0.7s
# [CV] END ......................max_depth=7, n_estimators=305; total time=   0.7s
# [CV] END ......................max_depth=7, n_estimators=305; total time=   0.6s
# [CV] END ......................max_depth=7, n_estimators=305; total time=   0.9s
# [CV] END ......................max_depth=7, n_estimators=305; total time=   0.7s
# [CV] END .....................max_depth=21, n_estimators=519; total time=   1.7s
# [CV] END .....................max_depth=21, n_estimators=519; total time=   1.6s
# [CV] END .....................max_depth=21, n_estimators=519; total time=   1.4s
# [CV] END .....................max_depth=21, n_estimators=519; total time=   1.8s
# [CV] END .....................max_depth=21, n_estimators=519; total time=   1.4s
# [CV] END .....................max_depth=22, n_estimators=459; total time=   1.3s
# [CV] END .....................max_depth=22, n_estimators=459; total time=   1.3s
# [CV] END .....................max_depth=22, n_estimators=459; total time=   1.3s
# [CV] END .....................max_depth=22, n_estimators=459; total time=   1.3s
# [CV] END .....................max_depth=22, n_estimators=459; total time=   1.3s
# [CV] END ......................max_depth=8, n_estimators=101; total time=   0.2s
# [CV] END ......................max_depth=8, n_estimators=101; total time=   0.2s
# [CV] END ......................max_depth=8, n_estimators=101; total time=   0.2s
# [CV] END ......................max_depth=8, n_estimators=101; total time=   0.2s
# [CV] END ......................max_depth=8, n_estimators=101; total time=   0.2s
# [CV] END .....................max_depth=10, n_estimators=153; total time=   0.3s
# [CV] END .....................max_depth=10, n_estimators=153; total time=   0.3s
# [CV] END .....................max_depth=10, n_estimators=153; total time=   0.3s
# [CV] END .....................max_depth=10, n_estimators=153; total time=   0.3s
# [CV] END .....................max_depth=10, n_estimators=153; total time=   0.6s
# [CV] END .....................max_depth=14, n_estimators=359; total time=   1.1s
# [CV] END .....................max_depth=14, n_estimators=359; total time=   1.0s
# [CV] END .....................max_depth=14, n_estimators=359; total time=   1.0s
# [CV] END .....................max_depth=14, n_estimators=359; total time=   1.0s
# [CV] END .....................max_depth=14, n_estimators=359; total time=   1.0s
# [CV] END .....................max_depth=26, n_estimators=576; total time=   1.7s
# [CV] END .....................max_depth=26, n_estimators=576; total time=   1.7s
# [CV] END .....................max_depth=26, n_estimators=576; total time=   2.5s
# [CV] END .....................max_depth=26, n_estimators=576; total time=   1.7s
# [CV] END .....................max_depth=26, n_estimators=576; total time=   1.7s
# [CV] END .....................max_depth=22, n_estimators=317; total time=   0.8s
# [CV] END .....................max_depth=22, n_estimators=317; total time=   0.8s
# [CV] END .....................max_depth=22, n_estimators=317; total time=   0.8s
# [CV] END .....................max_depth=22, n_estimators=317; total time=   0.8s
# [CV] END .....................max_depth=22, n_estimators=317; total time=   0.8s
# [CV] END .....................max_depth=16, n_estimators=261; total time=   0.7s
# [CV] END .....................max_depth=16, n_estimators=261; total time=   0.7s
# [CV] END .....................max_depth=16, n_estimators=261; total time=   0.7s
# [CV] END .....................max_depth=16, n_estimators=261; total time=   0.7s
# [CV] END .....................max_depth=16, n_estimators=261; total time=   0.7s
# [CV] END .....................max_depth=14, n_estimators=545; total time=   1.6s
# [CV] END .....................max_depth=14, n_estimators=545; total time=   1.5s
# [CV] END .....................max_depth=14, n_estimators=545; total time=   1.5s
# [CV] END .....................max_depth=14, n_estimators=545; total time=   1.5s
# [CV] END .....................max_depth=14, n_estimators=545; total time=   1.5s
# [CV] END ......................max_depth=8, n_estimators=369; total time=   0.8s
# [CV] END ......................max_depth=8, n_estimators=369; total time=   0.8s
# [CV] END ......................max_depth=8, n_estimators=369; total time=   0.8s
# [CV] END ......................max_depth=8, n_estimators=369; total time=   0.8s
# [CV] END ......................max_depth=8, n_estimators=369; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=370; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=370; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=370; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=370; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=370; total time=   1.1s
# [CV] END .....................max_depth=12, n_estimators=561; total time=   1.6s
# [CV] END .....................max_depth=12, n_estimators=561; total time=   2.8s
# [CV] END .....................max_depth=12, n_estimators=561; total time=   2.3s
# [CV] END .....................max_depth=12, n_estimators=561; total time=   2.0s
# [CV] END .....................max_depth=12, n_estimators=561; total time=   2.9s
# [CV] END .....................max_depth=27, n_estimators=351; total time=   1.3s
# [CV] END .....................max_depth=27, n_estimators=351; total time=   1.3s
# [CV] END .....................max_depth=27, n_estimators=351; total time=   1.2s
# [CV] END .....................max_depth=27, n_estimators=351; total time=   1.2s
# [CV] END .....................max_depth=27, n_estimators=351; total time=   1.2s
# [CV] END .....................max_depth=29, n_estimators=289; total time=   1.0s
# [CV] END .....................max_depth=29, n_estimators=289; total time=   1.0s
# [CV] END .....................max_depth=29, n_estimators=289; total time=   0.9s
# [CV] END .....................max_depth=29, n_estimators=289; total time=   0.9s
# [CV] END .....................max_depth=29, n_estimators=289; total time=   0.9s
# [CV] END .....................max_depth=12, n_estimators=312; total time=   1.0s
# [CV] END .....................max_depth=12, n_estimators=312; total time=   1.0s
# [CV] END .....................max_depth=12, n_estimators=312; total time=   0.9s
# [CV] END .....................max_depth=12, n_estimators=312; total time=   0.8s
# [CV] END .....................max_depth=12, n_estimators=312; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=336; total time=   1.0s
# [CV] END .....................max_depth=20, n_estimators=336; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=336; total time=   1.1s
# [CV] END .....................max_depth=20, n_estimators=336; total time=   1.4s
# [CV] END .....................max_depth=20, n_estimators=336; total time=   1.0s
# [CV] END .....................max_depth=22, n_estimators=466; total time=   1.4s
# [CV] END .....................max_depth=22, n_estimators=466; total time=   1.4s
# [CV] END .....................max_depth=22, n_estimators=466; total time=   1.4s
# [CV] END .....................max_depth=22, n_estimators=466; total time=   1.3s
# [CV] END .....................max_depth=22, n_estimators=466; total time=   1.3s
# [CV] END .....................max_depth=25, n_estimators=379; total time=   1.1s
# [CV] END .....................max_depth=25, n_estimators=379; total time=   1.1s
# [CV] END .....................max_depth=25, n_estimators=379; total time=   1.1s
# [CV] END .....................max_depth=25, n_estimators=379; total time=   1.1s
# [CV] END .....................max_depth=25, n_estimators=379; total time=   1.1s
# [CV] END .....................max_depth=30, n_estimators=316; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=316; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=316; total time=   0.8s
# [CV] END .....................max_depth=30, n_estimators=316; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=316; total time=   0.8s
# [CV] END .....................max_depth=17, n_estimators=140; total time=   0.3s
# [CV] END .....................max_depth=17, n_estimators=140; total time=   0.3s
# [CV] END .....................max_depth=17, n_estimators=140; total time=   0.3s
# [CV] END .....................max_depth=17, n_estimators=140; total time=   0.4s
# [CV] END .....................max_depth=17, n_estimators=140; total time=   0.3s
# [CV] END .....................max_depth=19, n_estimators=400; total time=   1.1s
# [CV] END .....................max_depth=19, n_estimators=400; total time=   1.2s
# [CV] END .....................max_depth=19, n_estimators=400; total time=   1.1s
# [CV] END .....................max_depth=19, n_estimators=400; total time=   1.2s
# [CV] END .....................max_depth=19, n_estimators=400; total time=   1.1s
# [CV] END ......................max_depth=5, n_estimators=444; total time=   0.9s
# [CV] END ......................max_depth=5, n_estimators=444; total time=   0.9s
# [CV] END ......................max_depth=5, n_estimators=444; total time=   0.8s
# [CV] END ......................max_depth=5, n_estimators=444; total time=   0.8s
# [CV] END ......................max_depth=5, n_estimators=444; total time=   0.9s
# [CV] END .....................max_depth=11, n_estimators=108; total time=   0.2s
# [CV] END .....................max_depth=11, n_estimators=108; total time=   0.2s
# [CV] END .....................max_depth=11, n_estimators=108; total time=   0.2s
# [CV] END .....................max_depth=11, n_estimators=108; total time=   0.2s
# [CV] END .....................max_depth=11, n_estimators=108; total time=   0.2s
# {'max_depth': 5, 'n_estimators': 444}
# 0.9184617636686652

# %%
pred_rf = rand_rf.predict(X_test_scal)
pred_proba_rf = rand_rf.predict_proba(X_test_scal)[:,1]

# %%
print('confusion_matrix: ', confusion_matrix(y_test, pred_rf))
print('accuracy_score: ', accuracy_score(y_test, pred_rf))
print('precision_score: ', precision_score(y_test, pred_rf))
print('recall_score: ', recall_score(y_test, pred_rf))
print('f1_score: ', f1_score(y_test, pred_rf))
print('roc_auc_score: ', roc_auc_score(y_test, pred_proba_rf))
# Out:
# confusion_matrix:  [[693  41]
#  [ 62 575]]
# accuracy_score:  0.924872355944566
# precision_score:  0.9334415584415584
# recall_score:  0.902668759811617
# f1_score:  0.9177972865123704
# roc_auc_score:  0.9805296882953559

# %% [markdown]
# ## ADA

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

base = DecisionTreeClassifier()

ada = AdaBoostClassifier(estimator=base)

param_dist = {
    "n_estimators": randint(50, 500),
    "learning_rate": uniform(0.01, 1.0),
    "estimator__max_depth": randint(1, 5),
    "estimator__min_samples_split": randint(2, 20),
}

rand_ada = RandomizedSearchCV(
    ada,
    param_distributions=param_dist,
    n_iter=60,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
    verbose=2,
    random_state=42
)

rand_ada.fit(X_train_scal, y_train)

print(rand_ada.best_params_)
print(rand_ada.best_score_)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'estimator__max_depth': 2, 'estimator__min_samples_split': 17, 'learning_rate': np.float64(0.05077514155476392), 'n_estimators': 197}
# 0.9211993226383834

# %%
pred_ada = rand_ada.predict(X_test_scal)
pred_proba_ada = rand_ada.predict_proba(X_test_scal)[:,1]

# %%
print('confusion_matrix: ', confusion_matrix(y_test, pred_ada))
print('accuracy_score: ', accuracy_score(y_test, pred_ada))
print('precision_score: ', precision_score(y_test, pred_ada))
print('recall_score: ', recall_score(y_test, pred_ada))
print('f1_score: ', f1_score(y_test, pred_ada))
print('roc_auc_score: ', roc_auc_score(y_test, pred_proba_ada))
# Out:
# confusion_matrix:  [[695  39]
#  [ 63 574]]
# accuracy_score:  0.925601750547046
# precision_score:  0.9363784665579119
# recall_score:  0.9010989010989011
# f1_score:  0.9184
# roc_auc_score:  0.9812878830006116

# %% [markdown]
# ## XGBoost

# %%
xgb = XGBClassifier(use_label_encoder=False, eval_metric="logloss", random_state=42)

param_grid = {
    "n_estimators": [150, 200,250],
    "max_depth": [3, 5, 7],
    "learning_rate": [0.01, 0.05],
    "subsample": [0.7, 0.85],
    "colsample_bytree": [0.85, 1.0],
    "gamma": [0, 1],
    "reg_alpha": [0.3, 0.5],
    "reg_lambda": [1, 1.5]
}

grid_xgb = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
    verbose=2
)

grid_xgb.fit(X_train_scal, y_train)
# Out:
# Fitting 5 folds for each of 576 candidates, totalling 2880 fits
# c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:199: UserWarning: [09:37:07] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric='logloss', feature_types=None,
#                                      feature_weights=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraint...
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.85, 1.0], 'gamma': [0, 1],
#                          'learning_rate': [0.01, 0.05], 'max_depth': [3, 5, 7],
#                          'n_estimators': [150, 200, 250],
#                          'reg_alpha': [0.3, 0.5], 'reg_lambda': [1, 1.5],
#                          'subsample': [0.7, 0.85]},
#              scoring='f1_macro', verbose=2)

# %%
print(grid_xgb.best_params_)
print(grid_xgb.best_score_)
# Out:
# {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 150, 'reg_alpha': 0.5, 'reg_lambda': 1, 'subsample': 0.7}
# 0.9235158801074569

# %%
pred_xgb = grid_xgb.predict(X_test_scal)
pred_proba_xgb = grid_xgb.predict_proba(X_test_scal)[:,1]

# %%
print('confusion_matrix: ', confusion_matrix(y_test, pred_xgb))
print('accuracy_score: ', accuracy_score(y_test, pred_xgb))
print('precision_score: ', precision_score(y_test, pred_xgb))
print('recall_score: ', recall_score(y_test, pred_xgb))
print('f1_score: ', f1_score(y_test, pred_xgb))
print('roc_auc_score: ', roc_auc_score(y_test, pred_proba_xgb))
# Out:
# confusion_matrix:  [[700  34]
#  [ 60 577]]
# accuracy_score:  0.9314369073668854
# precision_score:  0.9443535188216039
# recall_score:  0.9058084772370487
# f1_score:  0.9246794871794872
# roc_auc_score:  0.9810590343871775

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier()

# %%
param_grid_knn = {
    "n_neighbors": [1, 3, 5, 7, 9, 11, 15, 21],
    "weights": ["uniform", "distance"],
    "metric": ["euclidean", "manhattan", "minkowski"],
    "p": [1, 2]
}

grid_knn = GridSearchCV(
    estimator=knn,
    param_grid=param_grid_knn,
    cv=5,
    scoring="accuracy"
)

grid_knn.fit(X_train_scal, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [1, 3, 5, 7, 9, 11, 15, 21],
#                          'p': [1, 2], 'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
print("Mejores hiperparámetros:", grid_knn.best_params_)
print("Mejor score CV:", grid_knn.best_score_)
# Out:
# Mejores hiperparámetros: {'metric': 'manhattan', 'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}
# Mejor score CV: 0.9122575504527942

# %%
pred_knn = grid_knn.predict(X_test_scal)
pred_proba_knn = grid_knn.predict_proba(X_test_scal)[:,1]

# %%
print('confusion_matrix: ', confusion_matrix(y_test, pred_knn))
print('accuracy_score: ', accuracy_score(y_test, pred_knn))
print('precision_score: ', precision_score(y_test, pred_knn))
print('recall_score: ', recall_score(y_test, pred_knn))
print('f1_score: ', f1_score(y_test, pred_knn))
print('roc_auc_score: ', roc_auc_score(y_test, pred_proba_knn))
# Out:
# confusion_matrix:  [[681  53]
#  [ 65 572]]
# accuracy_score:  0.9139314369073669
# precision_score:  0.9152
# recall_score:  0.8979591836734694
# f1_score:  0.9064976228209192
# roc_auc_score:  0.9719040204637713

# %% [markdown]
# ## SVC

# %%
svc = SVC()

# %%
svc = SVC(probability=True)

param_grid_svc = {
    "C": [ 100,200],
    "kernel": ["rbf", 'poly'],
    "gamma": [0.01, 0.001],
    "degree": [2, 3, 4]
}

grid_svc = GridSearchCV(
    estimator=svc,
    param_grid=param_grid_svc,
    cv=3,
    scoring="accuracy",
    n_jobs=-1
)

grid_svc.fit(X_train_scal, y_train)
# Out:
# GridSearchCV(cv=3, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [100, 200], 'degree': [2, 3, 4],
#                          'gamma': [0.01, 0.001], 'kernel': ['rbf', 'poly']},
#              scoring='accuracy')

# %%
print("Mejores parámetros:", grid_svc.best_params_)
print("Mejor score CV:", grid_svc.best_score_)
# Out:
# Mejores parámetros: {'C': 100, 'degree': 2, 'gamma': 0.01, 'kernel': 'rbf'}
# Mejor score CV: 0.9217458800383422

# %%
pred_svc = grid_svc.predict(X_test_scal)
pred_proba_svc = grid_svc.predict_proba(X_test_scal)[:,1]

# %%
print('confusion_matrix: ', confusion_matrix(y_test, pred_svc))
print('accuracy_score: ', accuracy_score(y_test, pred_svc))
print('precision_score: ', precision_score(y_test, pred_svc))
print('recall_score: ', recall_score(y_test, pred_svc))
print('f1_score: ', f1_score(y_test, pred_svc))
print('roc_auc_score: ', roc_auc_score(y_test, pred_proba_svc))
# Out:
# confusion_matrix:  [[697  37]
#  [ 64 573]]
# accuracy_score:  0.9263311451495259
# precision_score:  0.9393442622950819
# recall_score:  0.8995290423861853
# f1_score:  0.9190056134723336
# roc_auc_score:  0.9749325217406183

# %% [markdown]
# ## KMEANS

# %%
kmeans = KMeans(n_clusters=2, n_init=15, random_state=42)

pred_kmeans = kmeans.fit_predict(X_scal)

# %%
pred_kmeans
# Out:
# array([1, 0, 1, ..., 1, 0, 0], shape=(6853,), dtype=int32)

# %%
pred_kmeans = 1 - pred_kmeans

# %%
np.sum(pred_kmeans==y) / len(pred_kmeans)
# Out:
# np.float64(0.845469137603969)

# %%
confusion_matrix(pred_kmeans, y)
# Out:
# array([[3073,  595],
#        [ 464, 2721]])

# %% [markdown]
# ## Keras Sequential

# %%
mod_seq = keras.Sequential([
    layers.Input(shape=(X_train_scal.shape[1],)),

    layers.Dense(256, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(128, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    layers.Dense(64, activation="relu"),
    layers.BatchNormalization(),

    layers.Dense(1, activation="sigmoid")
])

# %%
mod_seq.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
EarlyStopping(
    monitor="val_loss",
    patience=12,
    restore_best_weights=True
)

# %%
history = mod_seq.fit(
    X_train_scal,
    y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8851 - loss: 0.2996 - val_accuracy: 0.9170 - val_loss: 0.2381
# Epoch 2/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9076 - loss: 0.2289 - val_accuracy: 0.9134 - val_loss: 0.1924
# Epoch 3/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9081 - loss: 0.2212 - val_accuracy: 0.9070 - val_loss: 0.2007
# Epoch 4/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9088 - loss: 0.2162 - val_accuracy: 0.9125 - val_loss: 0.1940
# Epoch 5/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9149 - loss: 0.2070 - val_accuracy: 0.9161 - val_loss: 0.1924
# Epoch 6/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9129 - loss: 0.2112 - val_accuracy: 0.9198 - val_loss: 0.1855
# Epoch 7/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9104 - loss: 0.2026 - val_accuracy: 0.9116 - val_loss: 0.1926
# Epoch 8/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9106 - loss: 0.2072 - val_accuracy: 0.9253 - val_loss: 0.1915
# Epoch 9/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9204 - loss: 0.1963 - val_accuracy: 0.9207 - val_loss: 0.1871
# Epoch 10/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9124 - loss: 0.2052 - val_accuracy: 0.9161 - val_loss: 0.1869
# Epoch 11/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9117 - loss: 0.2044 - val_accuracy: 0.9234 - val_loss: 0.1882
# Epoch 12/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9231 - loss: 0.1941 - val_accuracy: 0.9207 - val_loss: 0.1866
# Epoch 13/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9133 - loss: 0.1960 - val_accuracy: 0.9161 - val_loss: 0.1901
# Epoch 14/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9140 - loss: 0.2032 - val_accuracy: 0.9116 - val_loss: 0.1922
# Epoch 15/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9204 - loss: 0.1901 - val_accuracy: 0.9079 - val_loss: 0.2004
# Epoch 16/200
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9170 - loss: 0.1887 - val_accuracy: 0.9189 - val_loss: 0.1949

# %%
mod_seq.evaluate(X_test_scal, y_test)
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9176 - loss: 0.1800
# [0.1800239235162735, 0.917578399181366]
