# %% [markdown]
# https://huggingface.co/datasets/gptilt/lol-basic-matches-challenger-10k/tree/main/matches

# %%
import pandas as pd

# %%
df1 = pd.read_parquet("data/region_americas-00000.parquet")
df1.to_csv("data/america.csv", index=False)

# %%
df2 = pd.read_parquet("data/region_asia-00000.parquet")
df2.to_csv("data/asia.csv", index=False)

# %%
df3 = pd.read_parquet("data/region_europe-00000.parquet")
df3.to_csv("data/europe.csv", index=False)

# %%
df1 = pd.read_csv("data/america.csv")
df2 = pd.read_csv("data/europe.csv")
df3 = pd.read_csv("data/asia.csv")

df = pd.concat([df1, df2, df3], ignore_index=True)
df
# Out:
#       endOfGameResult  gameDuration  gameEndTimestamp      gameId  \
# 0        GameComplete          1400     1745018960446  5269865992
# 1        GameComplete          1524     1744589457829  5266494442
# 2        GameComplete          1782     1744585171830  5266444763
# 3        GameComplete          1939     1744582474913  5266408515
# 4        GameComplete           930     1744576222010  5266355238
# ...               ...           ...               ...         ...
# 9997     GameComplete          2039     1742228942521  7564400504
# 9998     GameComplete          1768     1742225867891  7564345758
# 9999     GameComplete          1153     1742214911949  7564082053
# 10000    GameComplete          1264     1741530850044  7555030815
# 10001    GameComplete          1629     1743075444042   501487248
#
#        gameStartTimestamp    gameVersion         matchId platformId    region  \
# 0           1745017559681    15.8.675.10  NA1_5269865992        NA1  americas
# ...
